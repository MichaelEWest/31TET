# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

# %%
# "Inverse dwell time"
sample_rate = 4410

duration = 3  # Seconds
numpoint = duration*sample_rate

time = np.linspace(0,duration,int(sample_rate*duration),endpoint=False)
nu = np.arange(-0.5*sample_rate,0.5*sample_rate,numpoint)

# %%
time
# Out:
# array([0.00000000e+00, 2.26757370e-04, 4.53514739e-04, ...,
#        2.99931973e+00, 2.99954649e+00, 2.99977324e+00])

# %%
plt.plot(nu)

# %%
len(time)
# Out:
# 13230

# %%
1/(numpoint)*sample_rate*0.5
# Out:
# 0.16666666666666666
